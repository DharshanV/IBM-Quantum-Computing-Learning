# %%
import qiskit
from qiskit import QuantumCircuit, Aer, execute
from qiskit_textbook.widgets import plot_bloch_vector_spherical
from math import sqrt, pi

#|q⟩=cos(θ/2)|0⟩+e^(iϕ)sin(θ/2)|1⟩

# %%
vector = [0,0,1]
plot_bloch_vector_spherical(vector)

# %%
vector = [pi,0,1]
plot_bloch_vector_spherical(vector)

# %%
vector = [sqrt(1/2), sqrt(1/2),1]
plot_bloch_vector_spherical(vector)

# %%
vector = [pi/2,0,1]
plot_bloch_vector_spherical(vector)
